# %%
import nltk
nltk.download('punkt')
from nltk.tokenize import word_tokenize,sent_tokenize,TweetTokenizer,RegexpTokenizer
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.

# %%
 words = word_tokenize("Tendulkar took up cricket at the age of eleven")

# %%
print(words)
# Out:
# ['Tendulkar', 'took', 'up', 'cricket', 'at', 'the', 'age', 'of', 'eleven']

# %%
sentences = sent_tokenize("Tendulkar took up cricket at the age of eleven, made his Test debut on 15 November 1989 against Pakistan in Karachi at the age of sixteen, and went on to represent Mumbai domestically and India internationally for close to twenty-four years. In 2002, halfway through his career, Wisden Cricketers' Almanack ranked him the second-greatest Test batsman of all time, behind Don Bradman, and the second-greatest ODI batsman of all time, behind Viv Richards.")

# %%
print(sentences)
# Out:
# ['Tendulkar took up cricket at the age of eleven, made his Test debut on 15 November 1989 against Pakistan in Karachi at the age of sixteen, and went on to represent Mumbai domestically and India internationally for close to twenty-four years.', "In 2002, halfway through his career, Wisden Cricketers' Almanack ranked him the second-greatest Test batsman of all time, behind Don Bradman, and the second-greatest ODI batsman of all time, behind Viv Richards."]

# %%
words= [word_tokenize(sentence) for sentence in sentences]

# %%
print(words)
# Out:
# [['Tendulkar', 'took', 'up', 'cricket', 'at', 'the', 'age', 'of', 'eleven', ',', 'made', 'his', 'Test', 'debut', 'on', '15', 'November', '1989', 'against', 'Pakistan', 'in', 'Karachi', 'at', 'the', 'age', 'of', 'sixteen', ',', 'and', 'went', 'on', 'to', 'represent', 'Mumbai', 'domestically', 'and', 'India', 'internationally', 'for', 'close', 'to', 'twenty-four', 'years', '.'], ['In', '2002', ',', 'halfway', 'through', 'his', 'career', ',', 'Wisden', 'Cricketers', "'", 'Almanack', 'ranked', 'him', 'the', 'second-greatest', 'Test', 'batsman', 'of', 'all', 'time', ',', 'behind', 'Don', 'Bradman', ',', 'and', 'the', 'second-greatest', 'ODI', 'batsman', 'of', 'all', 'time', ',', 'behind', 'Viv', 'Richards', '.']]

# %%
twttokenizer=TweetTokenizer()
twttokenizer.tokenize("Never ask a girl who is a #Twitter addict why she's late :)")
# Out:
# ['Never',
#  'ask',
#  'a',
#  'girl',
#  'who',
#  'is',
#  'a',
#  '#Twitter',
#  'addict',
#  'why',
#  "she's",
#  'late',
#  ':)']

# %%
 words = word_tokenize("Never ask a girl who is a #Twitter addict why she's late :)")

# %%
print(words)
# Out:
# ['Never', 'ask', 'a', 'girl', 'who', 'is', 'a', '#', 'Twitter', 'addict', 'why', 'she', "'s", 'late', ':', ')']

# %%
rextokenizer=RegexpTokenizer('\s+',gaps=True)

# %%
rextokenizer.tokenize("Tendulkar took up cricket at the age of eleven")
# Out:
# ['Tendulkar', 'took', 'up', 'cricket', 'at', 'the', 'age', 'of', 'eleven']
