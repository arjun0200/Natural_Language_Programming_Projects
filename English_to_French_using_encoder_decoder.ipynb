# %%
# !wget  http://www.manythings.org/anki/fra-eng.zip
# Out:
# --2022-10-04 03:13:26--  http://www.manythings.org/anki/fra-eng.zip
# Resolving www.manythings.org (www.manythings.org)... 173.254.30.110
# Connecting to www.manythings.org (www.manythings.org)|173.254.30.110|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 6720195 (6.4M) [application/zip]
# Saving to: ‘fra-eng.zip’
#
# fra-eng.zip         100%[===================>]   6.41M  3.39MB/s    in 1.9s
#
# 2022-10-04 03:13:28 (3.39 MB/s) - ‘fra-eng.zip’ saved [6720195/6720195]

# %%
#importing libraries 
from __future__ import print_function

from keras.models import Model
from keras.layers import Input, LSTM, Dense
import numpy as np

# %%
import zipfile
with zipfile.ZipFile("/content/fra-eng.zip", 'r') as zip_ref:
    zip_ref.extractall("/content")

# %%
batch_s = 64  # Batch size for training.
epochs = 100  # Number of epochs to train for.
latent_dimension = 256  # Latent dimensionality of the encoding space.
number_samples = 10000  # Number of samples to train on.
# Path to the data txt file on disk.
data_path = 'fra.txt'

# %%
# Vectorize the data.
input_texts = []
target_texts = []
input_characters = set()
target_characters = set()
with open(data_path, 'r', encoding='utf-8') as f:
    lines = f.read().split('\n')
for line in lines[: min(number_samples, len(lines) - 1)]:
    input_text, target_text, _ = line.split('\t')
    # We use "tab" as the "start sequence" character
    # for the targets, and "\n" as "end sequence" character.
    target_text = '\t' + target_text + '\n'
    input_texts.append(input_text)
    target_texts.append(target_text)
    for char in input_text:
        if char not in input_characters:
            input_characters.add(char)
    for char in target_text:
        if char not in target_characters:
            target_characters.add(char)

input_characters = sorted(list(input_characters))
target_characters = sorted(list(target_characters))
num_encoder_tokens = len(input_characters)
num_decoder_tokens = len(target_characters)
max_encoder_seq_length = max([len(txt) for txt in input_texts])
max_decoder_seq_length = max([len(txt) for txt in target_texts])

# %%
print('Number of samples:', len(target_texts))
print('Number of unique input tokens:', num_encoder_tokens)
print('Number of unique output tokens:', num_decoder_tokens)
print('Max sequence length for inputs:', max_encoder_seq_length)
print('Max sequence length for outputs:', max_decoder_seq_length)
# Out:
# Number of samples: 10000
# Number of unique input tokens: 71
# Number of unique output tokens: 93
# Max sequence length for inputs: 15
# Max sequence length for outputs: 59

# %%
input_token_index = dict(
    [(char, i) for i, char in enumerate(input_characters)])
target_token_index = dict(
    [(char, i) for i, char in enumerate(target_characters)])

# %%
encoder_input_data = np.zeros(
    (len(input_texts), max_encoder_seq_length, num_encoder_tokens),
    dtype='float32')
decoder_input_data = np.zeros(
    (len(input_texts), max_decoder_seq_length, num_decoder_tokens),
    dtype='float32')
decoder_target_data = np.zeros(
    (len(input_texts), max_decoder_seq_length, num_decoder_tokens),
    dtype='float32')

# %%
for i, (input_text, target_text) in enumerate(zip(input_texts, target_texts)):
    for t, char in enumerate(input_text):
        encoder_input_data[i, t, input_token_index[char]] = 1.
    encoder_input_data[i, t + 1:, input_token_index[' ']] = 1.
    for t, char in enumerate(target_text):
        # decoder_target_data is ahead of decoder_input_data by one timestep
        decoder_input_data[i, t, target_token_index[char]] = 1.
        if t > 0:
            # decoder_target_data will be ahead by one timestep
            # and will not include the start character.
            decoder_target_data[i, t - 1, target_token_index[char]] = 1.
    decoder_input_data[i, t + 1:, target_token_index[' ']] = 1.
    decoder_target_data[i, t:, target_token_index[' ']] = 1.

# %%
# Define an input sequence and process it.
encoder_inputs = Input(shape=(None, num_encoder_tokens))
encoder = LSTM(latent_dimension, return_state=True)
encoder_outputs, state_h, state_c = encoder(encoder_inputs)
# We discard `encoder_outputs` and only keep the states.
encoder_states = [state_h, state_c]

# %%
# Set up the decoder, using `encoder_states` as initial state.
decoder_inputs = Input(shape=(None, num_decoder_tokens))
# We set up our decoder to return full output sequences,
# and to return internal states as well. We don't use the
# return states in the training model, but we will use them in inference.
decoder_lstm = LSTM(latent_dimension, return_sequences=True, return_state=True)
decoder_outputs, _, _ = decoder_lstm(decoder_inputs,
                                     initial_state=encoder_states)
decoder_dense = Dense(num_decoder_tokens, activation='softmax')
decoder_outputs = decoder_dense(decoder_outputs)

# %%
# Define the model that will turn
# `encoder_input_data` & `decoder_input_data` into `decoder_target_data`
model = Model([encoder_inputs, decoder_inputs], decoder_outputs)

# %%
# Run training
model.compile(optimizer='rmsprop', loss='categorical_crossentropy',
              metrics=['accuracy'])
model.fit([encoder_input_data, decoder_input_data], decoder_target_data,
          batch_size=batch_s,
          epochs=epochs,
          validation_split=0.2)
# Out:
# Epoch 1/100
# 125/125 [==============================] - 6s 19ms/step - loss: 1.1352 - accuracy: 0.7377 - val_loss: 1.0116 - val_accuracy: 0.7209
# Epoch 2/100
# 125/125 [==============================] - 1s 12ms/step - loss: 0.8105 - accuracy: 0.7811 - val_loss: 0.8115 - val_accuracy: 0.7746
# Epoch 3/100
# 125/125 [==============================] - 1s 12ms/step - loss: 0.6438 - accuracy: 0.8185 - val_loss: 0.6881 - val_accuracy: 0.8004
# Epoch 4/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.5633 - accuracy: 0.8364 - val_loss: 0.6417 - val_accuracy: 0.8135
# Epoch 5/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.5163 - accuracy: 0.8490 - val_loss: 0.5753 - val_accuracy: 0.8330
# Epoch 6/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.4823 - accuracy: 0.8582 - val_loss: 0.5486 - val_accuracy: 0.8399
# Epoch 7/100
# 125/125 [==============================] - 1s 12ms/step - loss: 0.4552 - accuracy: 0.8649 - val_loss: 0.5307 - val_accuracy: 0.8437
# Epoch 8/100
# 125/125 [==============================] - 1s 12ms/step - loss: 0.4325 - accuracy: 0.8711 - val_loss: 0.5080 - val_accuracy: 0.8510
# Epoch 9/100
# 125/125 [==============================] - 1s 12ms/step - loss: 0.4131 - accuracy: 0.8766 - val_loss: 0.5021 - val_accuracy: 0.8520
# Epoch 10/100
# 125/125 [==============================] - 1s 12ms/step - loss: 0.3951 - accuracy: 0.8814 - val_loss: 0.4934 - val_accuracy: 0.8546
# Epoch 11/100
# 125/125 [==============================] - 2s 13ms/step - loss: 0.3783 - accuracy: 0.8863 - val_loss: 0.4771 - val_accuracy: 0.8593
# Epoch 12/100
# 125/125 [==============================] - 1s 12ms/step - loss: 0.3629 - accuracy: 0.8907 - val_loss: 0.4656 - val_accuracy: 0.8629
# Epoch 13/100
# 125/125 [==============================] - 1s 12ms/step - loss: 0.3485 - accuracy: 0.8946 - val_loss: 0.4593 - val_accuracy: 0.8649
# Epoch 14/100
# 125/125 [==============================] - 1s 12ms/step - loss: 0.3348 - accuracy: 0.8988 - val_loss: 0.4557 - val_accuracy: 0.8659
# Epoch 15/100
# 125/125 [==============================] - 1s 12ms/step - loss: 0.3222 - accuracy: 0.9024 - val_loss: 0.4526 - val_accuracy: 0.8673
# Epoch 16/100
# 125/125 [==============================] - 2s 12ms/step - loss: 0.3096 - accuracy: 0.9066 - val_loss: 0.4464 - val_accuracy: 0.8692
# Epoch 17/100
# 125/125 [==============================] - 1s 12ms/step - loss: 0.2983 - accuracy: 0.9096 - val_loss: 0.4438 - val_accuracy: 0.8706
# Epoch 18/100
# 125/125 [==============================] - 1s 12ms/step - loss: 0.2875 - accuracy: 0.9126 - val_loss: 0.4448 - val_accuracy: 0.8713
# Epoch 19/100
# 125/125 [==============================] - 1s 12ms/step - loss: 0.2771 - accuracy: 0.9162 - val_loss: 0.4426 - val_accuracy: 0.8739
# Epoch 20/100
# 125/125 [==============================] - 1s 12ms/step - loss: 0.2669 - accuracy: 0.9190 - val_loss: 0.4433 - val_accuracy: 0.8731
# Epoch 21/100
# 125/125 [==============================] - 1s 12ms/step - loss: 0.2573 - accuracy: 0.9221 - val_loss: 0.4433 - val_accuracy: 0.8735
# Epoch 22/100
# 125/125 [==============================] - 1s 12ms/step - loss: 0.2483 - accuracy: 0.9244 - val_loss: 0.4435 - val_accuracy: 0.8746
# Epoch 23/100
# 125/125 [==============================] - 1s 12ms/step - loss: 0.2400 - accuracy: 0.9274 - val_loss: 0.4439 - val_accuracy: 0.8748
# Epoch 24/100
# 125/125 [==============================] - 1s 12ms/step - loss: 0.2315 - accuracy: 0.9296 - val_loss: 0.4482 - val_accuracy: 0.8752
# Epoch 25/100
# 125/125 [==============================] - 1s 12ms/step - loss: 0.2236 - accuracy: 0.9322 - val_loss: 0.4484 - val_accuracy: 0.8759
# Epoch 26/100
# 125/125 [==============================] - 1s 12ms/step - loss: 0.2159 - accuracy: 0.9346 - val_loss: 0.4564 - val_accuracy: 0.8746
# Epoch 27/100
# 125/125 [==============================] - 2s 12ms/step - loss: 0.2084 - accuracy: 0.9366 - val_loss: 0.4561 - val_accuracy: 0.8758
# Epoch 28/100
# 125/125 [==============================] - 1s 12ms/step - loss: 0.2016 - accuracy: 0.9384 - val_loss: 0.4594 - val_accuracy: 0.8749
# Epoch 29/100
# 125/125 [==============================] - 2s 12ms/step - loss: 0.1949 - accuracy: 0.9406 - val_loss: 0.4601 - val_accuracy: 0.8758
# Epoch 30/100
# 125/125 [==============================] - 1s 12ms/step - loss: 0.1887 - accuracy: 0.9425 - val_loss: 0.4684 - val_accuracy: 0.8749
# Epoch 31/100
# 125/125 [==============================] - 2s 12ms/step - loss: 0.1826 - accuracy: 0.9444 - val_loss: 0.4692 - val_accuracy: 0.8759
# Epoch 32/100
# 125/125 [==============================] - 2s 12ms/step - loss: 0.1763 - accuracy: 0.9460 - val_loss: 0.4752 - val_accuracy: 0.8759
# Epoch 33/100
# 125/125 [==============================] - 2s 12ms/step - loss: 0.1709 - accuracy: 0.9478 - val_loss: 0.4730 - val_accuracy: 0.8768
# Epoch 34/100
# 125/125 [==============================] - 2s 12ms/step - loss: 0.1655 - accuracy: 0.9491 - val_loss: 0.4846 - val_accuracy: 0.8757
# Epoch 35/100
# 125/125 [==============================] - 2s 12ms/step - loss: 0.1600 - accuracy: 0.9511 - val_loss: 0.4878 - val_accuracy: 0.8760
# Epoch 36/100
# 125/125 [==============================] - 2s 12ms/step - loss: 0.1553 - accuracy: 0.9520 - val_loss: 0.4913 - val_accuracy: 0.8760
# Epoch 37/100
# 125/125 [==============================] - 2s 12ms/step - loss: 0.1507 - accuracy: 0.9535 - val_loss: 0.4944 - val_accuracy: 0.8755
# Epoch 38/100
# 125/125 [==============================] - 2s 12ms/step - loss: 0.1457 - accuracy: 0.9550 - val_loss: 0.5037 - val_accuracy: 0.8748
# Epoch 39/100
# 125/125 [==============================] - 2s 14ms/step - loss: 0.1419 - accuracy: 0.9564 - val_loss: 0.5013 - val_accuracy: 0.8754
# Epoch 40/100
# 125/125 [==============================] - 2s 15ms/step - loss: 0.1378 - accuracy: 0.9576 - val_loss: 0.5044 - val_accuracy: 0.8764
# Epoch 41/100
# 125/125 [==============================] - 1s 12ms/step - loss: 0.1337 - accuracy: 0.9586 - val_loss: 0.5123 - val_accuracy: 0.8758
# Epoch 42/100
# 125/125 [==============================] - 2s 12ms/step - loss: 0.1297 - accuracy: 0.9600 - val_loss: 0.5259 - val_accuracy: 0.8748
# Epoch 43/100
# 125/125 [==============================] - 2s 14ms/step - loss: 0.1260 - accuracy: 0.9608 - val_loss: 0.5189 - val_accuracy: 0.8761
# Epoch 44/100
# 125/125 [==============================] - 2s 14ms/step - loss: 0.1227 - accuracy: 0.9620 - val_loss: 0.5313 - val_accuracy: 0.8747
# Epoch 45/100
# 125/125 [==============================] - 1s 12ms/step - loss: 0.1192 - accuracy: 0.9631 - val_loss: 0.5306 - val_accuracy: 0.8752
# Epoch 46/100
# 125/125 [==============================] - 1s 12ms/step - loss: 0.1159 - accuracy: 0.9640 - val_loss: 0.5400 - val_accuracy: 0.8744
# Epoch 47/100
# 125/125 [==============================] - 1s 12ms/step - loss: 0.1126 - accuracy: 0.9649 - val_loss: 0.5486 - val_accuracy: 0.8744
# Epoch 48/100
# 125/125 [==============================] - 1s 12ms/step - loss: 0.1097 - accuracy: 0.9659 - val_loss: 0.5548 - val_accuracy: 0.8748
# Epoch 49/100
# 125/125 [==============================] - 1s 12ms/step - loss: 0.1067 - accuracy: 0.9666 - val_loss: 0.5578 - val_accuracy: 0.8746
# Epoch 50/100
# 125/125 [==============================] - 1s 12ms/step - loss: 0.1041 - accuracy: 0.9673 - val_loss: 0.5643 - val_accuracy: 0.8743
# Epoch 51/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.1012 - accuracy: 0.9683 - val_loss: 0.5699 - val_accuracy: 0.8738
# Epoch 52/100
# 125/125 [==============================] - 1s 12ms/step - loss: 0.0986 - accuracy: 0.9690 - val_loss: 0.5677 - val_accuracy: 0.8746
# Epoch 53/100
# 125/125 [==============================] - 1s 12ms/step - loss: 0.0963 - accuracy: 0.9697 - val_loss: 0.5726 - val_accuracy: 0.8751
# Epoch 54/100
# 125/125 [==============================] - 1s 12ms/step - loss: 0.0938 - accuracy: 0.9705 - val_loss: 0.5833 - val_accuracy: 0.8740
# Epoch 55/100
# 125/125 [==============================] - 1s 12ms/step - loss: 0.0917 - accuracy: 0.9712 - val_loss: 0.5896 - val_accuracy: 0.8739
# Epoch 56/100
# 125/125 [==============================] - 2s 12ms/step - loss: 0.0894 - accuracy: 0.9717 - val_loss: 0.5932 - val_accuracy: 0.8743
# Epoch 57/100
# 125/125 [==============================] - 1s 12ms/step - loss: 0.0870 - accuracy: 0.9721 - val_loss: 0.6050 - val_accuracy: 0.8731
# Epoch 58/100
# 125/125 [==============================] - 2s 12ms/step - loss: 0.0853 - accuracy: 0.9727 - val_loss: 0.6025 - val_accuracy: 0.8734
# Epoch 59/100
# 125/125 [==============================] - 1s 12ms/step - loss: 0.0833 - accuracy: 0.9734 - val_loss: 0.6040 - val_accuracy: 0.8739
# Epoch 60/100
# 125/125 [==============================] - 1s 12ms/step - loss: 0.0815 - accuracy: 0.9738 - val_loss: 0.6145 - val_accuracy: 0.8737
# Epoch 61/100
# 125/125 [==============================] - 2s 12ms/step - loss: 0.0793 - accuracy: 0.9745 - val_loss: 0.6192 - val_accuracy: 0.8731
# Epoch 62/100
# 125/125 [==============================] - 1s 12ms/step - loss: 0.0778 - accuracy: 0.9749 - val_loss: 0.6241 - val_accuracy: 0.8730
# Epoch 63/100
# 125/125 [==============================] - 1s 12ms/step - loss: 0.0759 - accuracy: 0.9755 - val_loss: 0.6272 - val_accuracy: 0.8733
# Epoch 64/100
# 125/125 [==============================] - 1s 12ms/step - loss: 0.0744 - accuracy: 0.9760 - val_loss: 0.6338 - val_accuracy: 0.8741
# Epoch 65/100
# 125/125 [==============================] - 2s 12ms/step - loss: 0.0729 - accuracy: 0.9762 - val_loss: 0.6349 - val_accuracy: 0.8728
# Epoch 66/100
# 125/125 [==============================] - 2s 12ms/step - loss: 0.0712 - accuracy: 0.9765 - val_loss: 0.6427 - val_accuracy: 0.8727
# Epoch 67/100
# 125/125 [==============================] - 2s 12ms/step - loss: 0.0698 - accuracy: 0.9771 - val_loss: 0.6495 - val_accuracy: 0.8718
# Epoch 68/100
# 125/125 [==============================] - 1s 12ms/step - loss: 0.0684 - accuracy: 0.9778 - val_loss: 0.6510 - val_accuracy: 0.8720
# Epoch 69/100
# 125/125 [==============================] - 1s 12ms/step - loss: 0.0671 - accuracy: 0.9779 - val_loss: 0.6516 - val_accuracy: 0.8731
# Epoch 70/100
# 125/125 [==============================] - 1s 12ms/step - loss: 0.0656 - accuracy: 0.9783 - val_loss: 0.6638 - val_accuracy: 0.8725
# Epoch 71/100
# 125/125 [==============================] - 1s 12ms/step - loss: 0.0641 - accuracy: 0.9787 - val_loss: 0.6629 - val_accuracy: 0.8725
# Epoch 72/100
# 125/125 [==============================] - 1s 12ms/step - loss: 0.0630 - accuracy: 0.9790 - val_loss: 0.6644 - val_accuracy: 0.8728
# Epoch 73/100
# 125/125 [==============================] - 1s 12ms/step - loss: 0.0617 - accuracy: 0.9795 - val_loss: 0.6696 - val_accuracy: 0.8729
# Epoch 74/100
# 125/125 [==============================] - 1s 12ms/step - loss: 0.0607 - accuracy: 0.9797 - val_loss: 0.6741 - val_accuracy: 0.8722
# Epoch 75/100
# 125/125 [==============================] - 2s 12ms/step - loss: 0.0595 - accuracy: 0.9801 - val_loss: 0.6770 - val_accuracy: 0.8721
# Epoch 76/100
# 125/125 [==============================] - 2s 12ms/step - loss: 0.0587 - accuracy: 0.9802 - val_loss: 0.6804 - val_accuracy: 0.8728
# Epoch 77/100
# 125/125 [==============================] - 1s 12ms/step - loss: 0.0578 - accuracy: 0.9804 - val_loss: 0.6855 - val_accuracy: 0.8733
# Epoch 78/100
# 125/125 [==============================] - 1s 12ms/step - loss: 0.0567 - accuracy: 0.9806 - val_loss: 0.6881 - val_accuracy: 0.8723
# Epoch 79/100
# 125/125 [==============================] - 1s 12ms/step - loss: 0.0557 - accuracy: 0.9810 - val_loss: 0.6925 - val_accuracy: 0.8721
# Epoch 80/100
# 125/125 [==============================] - 1s 12ms/step - loss: 0.0546 - accuracy: 0.9814 - val_loss: 0.6936 - val_accuracy: 0.8719
# Epoch 81/100
# 125/125 [==============================] - 1s 12ms/step - loss: 0.0536 - accuracy: 0.9816 - val_loss: 0.6967 - val_accuracy: 0.8729
# Epoch 82/100
# 125/125 [==============================] - 2s 12ms/step - loss: 0.0528 - accuracy: 0.9817 - val_loss: 0.7022 - val_accuracy: 0.8724
# Epoch 83/100
# 125/125 [==============================] - 1s 12ms/step - loss: 0.0522 - accuracy: 0.9820 - val_loss: 0.7069 - val_accuracy: 0.8717
# Epoch 84/100
# 125/125 [==============================] - 2s 12ms/step - loss: 0.0515 - accuracy: 0.9822 - val_loss: 0.7045 - val_accuracy: 0.8727
# Epoch 85/100
# 125/125 [==============================] - 2s 12ms/step - loss: 0.0508 - accuracy: 0.9824 - val_loss: 0.7152 - val_accuracy: 0.8717
# Epoch 86/100
# 125/125 [==============================] - 1s 12ms/step - loss: 0.0501 - accuracy: 0.9825 - val_loss: 0.7192 - val_accuracy: 0.8716
# Epoch 87/100
# 125/125 [==============================] - 1s 12ms/step - loss: 0.0494 - accuracy: 0.9826 - val_loss: 0.7220 - val_accuracy: 0.8711
# Epoch 88/100
# 125/125 [==============================] - 1s 12ms/step - loss: 0.0487 - accuracy: 0.9829 - val_loss: 0.7212 - val_accuracy: 0.8726
# Epoch 89/100
# 125/125 [==============================] - 2s 12ms/step - loss: 0.0479 - accuracy: 0.9831 - val_loss: 0.7262 - val_accuracy: 0.8730
# Epoch 90/100
# 125/125 [==============================] - 1s 12ms/step - loss: 0.0472 - accuracy: 0.9834 - val_loss: 0.7260 - val_accuracy: 0.8712
# Epoch 91/100
# 125/125 [==============================] - 1s 12ms/step - loss: 0.0466 - accuracy: 0.9838 - val_loss: 0.7349 - val_accuracy: 0.8717
# Epoch 92/100
# 125/125 [==============================] - 1s 12ms/step - loss: 0.0462 - accuracy: 0.9835 - val_loss: 0.7358 - val_accuracy: 0.8726
# Epoch 93/100
# 125/125 [==============================] - 2s 12ms/step - loss: 0.0452 - accuracy: 0.9839 - val_loss: 0.7404 - val_accuracy: 0.8717
# Epoch 94/100
# 125/125 [==============================] - 1s 12ms/step - loss: 0.0449 - accuracy: 0.9840 - val_loss: 0.7423 - val_accuracy: 0.8714
# Epoch 95/100
# 125/125 [==============================] - 1s 12ms/step - loss: 0.0446 - accuracy: 0.9841 - val_loss: 0.7391 - val_accuracy: 0.8714
# Epoch 96/100
# 125/125 [==============================] - 2s 12ms/step - loss: 0.0440 - accuracy: 0.9843 - val_loss: 0.7449 - val_accuracy: 0.8718
# Epoch 97/100
# 125/125 [==============================] - 2s 12ms/step - loss: 0.0438 - accuracy: 0.9842 - val_loss: 0.7456 - val_accuracy: 0.8718
# Epoch 98/100
# 125/125 [==============================] - 1s 12ms/step - loss: 0.0431 - accuracy: 0.9843 - val_loss: 0.7512 - val_accuracy: 0.8722
# Epoch 99/100
# 125/125 [==============================] - 1s 12ms/step - loss: 0.0426 - accuracy: 0.9846 - val_loss: 0.7476 - val_accuracy: 0.8725
# Epoch 100/100
# 125/125 [==============================] - 1s 12ms/step - loss: 0.0421 - accuracy: 0.9847 - val_loss: 0.7551 - val_accuracy: 0.8717

# %%
# Save model
model.save('seq2seq.h5')

# %%
# Next: inference mode (sampling).
# Here's the drill:
# 1) encode input and retrieve initial decoder state
# 2) run one step of decoder with this initial state
# and a "start of sequence" token as target.
# Output will be the next target token
# 3) Repeat with the current target token and current states

# Define sampling models
encoder_model = Model(encoder_inputs, encoder_states)

decoder_state_input_h = Input(shape=(latent_dimension,))
decoder_state_input_c = Input(shape=(latent_dimension,))
decoder_states_inputs = [decoder_state_input_h, decoder_state_input_c]
decoder_outputs, state_h, state_c = decoder_lstm(
    decoder_inputs, initial_state=decoder_states_inputs)
decoder_states = [state_h, state_c]
decoder_outputs = decoder_dense(decoder_outputs)
decoder_model = Model(
    [decoder_inputs] + decoder_states_inputs,
    [decoder_outputs] + decoder_states)

# %%
# Reverse-lookup token index to decode sequences back to
# something readable.
reverse_input_char_index = dict(
    (i, char) for char, i in input_token_index.items())
reverse_target_char_index = dict(
    (i, char) for char, i in target_token_index.items())

# %%
def decode_sequence(input_seq):
    # Encode the input as state vectors.
    states_value = encoder_model.predict(input_seq)

    # Generate empty target sequence of length 1.
    target_seq = np.zeros((1, 1, num_decoder_tokens))
    # Populate the first character of target sequence with the start character.
    target_seq[0, 0, target_token_index['\t']] = 1.

    # Sampling loop for a batch of sequences
    # (to simplify, here we assume a batch of size 1).
    stop_condition = False
    decoded_sentence = ''
    while not stop_condition:
        output_tokens, h, c = decoder_model.predict(
            [target_seq] + states_value)

        # Sample a token
        sampled_token_index = np.argmax(output_tokens[0, -1, :])
        sampled_char = reverse_target_char_index[sampled_token_index]
        decoded_sentence += sampled_char

        # Exit condition: either hit max length
        # or find stop character.
        if (sampled_char == '\n' or
           len(decoded_sentence) > max_decoder_seq_length):
            stop_condition = True

        # Update the target sequence (of length 1).
        target_seq = np.zeros((1, 1, num_decoder_tokens))
        target_seq[0, 0, sampled_token_index] = 1.

        # Update states
        states_value = [h, c]

    return decoded_sentence

# %%
for seq_index in range(100):
    # Take one sequence (part of the training set)
    # for trying out decoding.
    input_seq = encoder_input_data[seq_index: seq_index + 1]
    decoded_sentence = decode_sequence(input_seq)
    print('-')
    print('Input sentence:', input_texts[seq_index])
    print('Decoded sentence:', decoded_sentence)
# Out:
# -
# Input sentence: Go.
# Decoded sentence: Va !
#
# -
# Input sentence: Go.
# Decoded sentence: Va !
#
# -
# Input sentence: Go.
# Decoded sentence: Va !
#
# -
# Input sentence: Go.
# Decoded sentence: Va !
#
# -
# Input sentence: Hi.
# Decoded sentence: Salut.
#
# -
# Input sentence: Hi.
# Decoded sentence: Salut.
#
# -
# Input sentence: Run!
# Decoded sentence: File !
#
# -
# Input sentence: Run!
# Decoded sentence: File !
#
# -
# Input sentence: Run!
# Decoded sentence: File !
#
# -
# Input sentence: Run!
# Decoded sentence: File !
#
# -
# Input sentence: Run!
# Decoded sentence: File !
#
# -
# Input sentence: Run!
# Decoded sentence: File !
#
# -
# Input sentence: Run!
# Decoded sentence: File !
#
# -
# Input sentence: Run!
# Decoded sentence: File !
#
# -
# Input sentence: Run.
# Decoded sentence: Filez !
#
# -
# Input sentence: Run.
# Decoded sentence: Filez !
#
# -
# Input sentence: Run.
# Decoded sentence: Filez !
#
# -
# Input sentence: Run.
# Decoded sentence: Filez !
#
# -
# Input sentence: Run.
# Decoded sentence: Filez !
#
# -
# Input sentence: Run.
# Decoded sentence: Filez !
#
# -
# Input sentence: Run.
# Decoded sentence: Filez !
#
# -
# Input sentence: Run.
# Decoded sentence: Filez !
#
# -
# Input sentence: Who?
# Decoded sentence: Qui ?
#
# -
# Input sentence: Wow!
# Decoded sentence: Waouh !
#
# -
# Input sentence: Wow!
# Decoded sentence: Waouh !
#
# -
# Input sentence: Wow!
# Decoded sentence: Waouh !
#
# -
# Input sentence: Duck!
# Decoded sentence: Baisse-toi !
#
# -
# Input sentence: Duck!
# Decoded sentence: Baisse-toi !
#
# -
# Input sentence: Duck!
# Decoded sentence: Baisse-toi !
#
# -
# Input sentence: Fire!
# Decoded sentence: Au feu !
#
# -
# Input sentence: Help!
# Decoded sentence: À l'aide !
#
# -
# Input sentence: Hide.
# Decoded sentence: Cachez-vous.
#
# -
# Input sentence: Hide.
# Decoded sentence: Cachez-vous.
#
# -
# Input sentence: Jump!
# Decoded sentence: Saute.
#
# -
# Input sentence: Jump.
# Decoded sentence: Saute.
#
# -
# Input sentence: Stop!
# Decoded sentence: Arrête-toi !
#
# -
# Input sentence: Stop!
# Decoded sentence: Arrête-toi !
#
# -
# Input sentence: Stop!
# Decoded sentence: Arrête-toi !
#
# -
# Input sentence: Wait!
# Decoded sentence: Attends !
#
# -
# Input sentence: Wait!
# Decoded sentence: Attends !
#
# -
# Input sentence: Wait!
# Decoded sentence: Attends !
#
# -
# Input sentence: Wait.
# Decoded sentence: Attends !
#
# -
# Input sentence: Wait.
# Decoded sentence: Attends !
#
# -
# Input sentence: Wait.
# Decoded sentence: Attends !
#
# -
# Input sentence: Wait.
# Decoded sentence: Attends !
#
# -
# Input sentence: Begin.
# Decoded sentence: Commence.
#
# -
# Input sentence: Begin.
# Decoded sentence: Commence.
#
# -
# Input sentence: Go on.
# Decoded sentence: Poursuis.
#
# -
# Input sentence: Go on.
# Decoded sentence: Poursuis.
#
# -
# Input sentence: Go on.
# Decoded sentence: Poursuis.
#
# -
# Input sentence: Hello!
# Decoded sentence: Salut !
#
# -
# Input sentence: Hello!
# Decoded sentence: Salut !
#
# -
# Input sentence: I see.
# Decoded sentence: Aha.
#
# -
# Input sentence: I see.
# Decoded sentence: Aha.
#
# -
# Input sentence: I try.
# Decoded sentence: J'essaye.
#
# -
# Input sentence: I won!
# Decoded sentence: Je l'ai emporté !
#
# -
# Input sentence: I won!
# Decoded sentence: Je l'ai emporté !
#
# -
# Input sentence: I won.
# Decoded sentence: J'ai gagné.
#
# -
# Input sentence: Oh no!
# Decoded sentence: Oh non !
#
# -
# Input sentence: Relax.
# Decoded sentence: Détends-toi !
#
# -
# Input sentence: Relax.
# Decoded sentence: Détends-toi !
#
# -
# Input sentence: Relax.
# Decoded sentence: Détends-toi !
#
# -
# Input sentence: Relax.
# Decoded sentence: Détends-toi !
#
# -
# Input sentence: Relax.
# Decoded sentence: Détends-toi !
#
# -
# Input sentence: Relax.
# Decoded sentence: Détends-toi !
#
# -
# Input sentence: Relax.
# Decoded sentence: Détends-toi !
#
# -
# Input sentence: Relax.
# Decoded sentence: Détends-toi !
#
# -
# Input sentence: Relax.
# Decoded sentence: Détends-toi !
#
# -
# Input sentence: Relax.
# Decoded sentence: Détends-toi !
#
# -
# Input sentence: Relax.
# Decoded sentence: Détends-toi !
#
# -
# Input sentence: Relax.
# Decoded sentence: Détends-toi !
#
# -
# Input sentence: Smile.
# Decoded sentence: Souriez !
#
# -
# Input sentence: Smile.
# Decoded sentence: Souriez !
#
# -
# Input sentence: Smile.
# Decoded sentence: Souriez !
#
# -
# Input sentence: Sorry?
# Decoded sentence: Pardon ?
#
# -
# Input sentence: Attack!
# Decoded sentence: Attaquez !
#
# -
# Input sentence: Attack!
# Decoded sentence: Attaquez !
#
# -
# Input sentence: Attack!
# Decoded sentence: Attaquez !
#
# -
# Input sentence: Attack!
# Decoded sentence: Attaquez !
#
# -
# Input sentence: Buy it.
# Decoded sentence: Achète-le !
#
# -
# Input sentence: Buy it.
# Decoded sentence: Achète-le !
#
# -
# Input sentence: Buy it.
# Decoded sentence: Achète-le !
#
# -
# Input sentence: Buy it.
# Decoded sentence: Achète-le !
#
# -
# Input sentence: Cheers!
# Decoded sentence: Santé !
#
# -
# Input sentence: Cheers!
# Decoded sentence: Santé !
#
# -
# Input sentence: Cheers!
# Decoded sentence: Santé !
#
# -
# Input sentence: Cheers!
# Decoded sentence: Santé !
#
# -
# Input sentence: Eat it.
# Decoded sentence: Mangez-le.
#
# -
# Input sentence: Eat it.
# Decoded sentence: Mangez-le.
#
# -
# Input sentence: Get up.
# Decoded sentence: Lève-toi.
#
# -
# Input sentence: Get up.
# Decoded sentence: Lève-toi.
#
# -
# Input sentence: Get up.
# Decoded sentence: Lève-toi.
#
# -
# Input sentence: Go now.
# Decoded sentence: Va, maintenant.
#
# -
# Input sentence: Go now.
# Decoded sentence: Va, maintenant.
#
# -
# Input sentence: Go now.
# Decoded sentence: Va, maintenant.
#
# -
# Input sentence: Got it!
# Decoded sentence: Aha !
#
# -
# Input sentence: Got it!
# Decoded sentence: Aha !
#
# -
# Input sentence: Got it!
# Decoded sentence: Aha !
#
# -
# Input sentence: Got it?
# Decoded sentence: T'as capté ?
#
# -
# Input sentence: Got it?
# Decoded sentence: T'as capté ?
